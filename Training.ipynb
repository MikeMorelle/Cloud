# %%
pip install ultralytics

# %%
import kagglehub

# Datensatz >35k
path = kagglehub.dataset_download("roscoekerby/firesmoke-detection-yolo-v9")

print("Path to dataset files:", path)
# Out:
# Using Colab cache for faster access to the 'firesmoke-detection-yolo-v9' dataset.
# Path to dataset files: /kaggle/input/firesmoke-detection-yolo-v9

# %%
from ultralytics import YOLO
#Starte mit vortrainierten
model = YOLO("yolo26n.pt")

# "kurzes" Training
results = model.train(data="/kaggle/input/firesmoke-detection-yolo-v9", epochs=20, imgsz=640, fraction=0.2)
# Out:
# Ultralytics 8.4.45 🚀 Python-3.12.13 torch-2.10.0+cu128 CUDA:0 (Tesla T4, 14913MiB)
# ...

# %% [markdown]
# ![grafik.png](data:image/png;base64,...)

# %% [markdown]
# Ausbaufähig...
